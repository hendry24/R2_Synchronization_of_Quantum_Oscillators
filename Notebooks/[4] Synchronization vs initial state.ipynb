# %%
import numpy as np
import matplotlib.pyplot as plt
import qutip as qt
import pyqosc as qo
import scipy as sp

options = qt.Options(nsteps = int(1e9))
plt.rcParams.update({"font.size" : 13})

# %%
def sim(N, n):

    fig, ax = plt.subplots(1,1, figsize = (10,5))

    vdp = qo.vdp(N = N, omega = 1.1)
    Ham, c_ops = vdp.dynamics()
    rho_ss = qt.steadystate(Ham, c_ops)

    out_lst = []
    theta_lst = np.linspace(0, 2*np.pi, 37)[:-1]
    for theta in theta_lst:
        out_lst.append(qo.qdistance_to_ss(Ham = Ham,
                        c_ops = c_ops,
                        rho0 = qt.coherent_dm(N, n * np.exp(1j*theta)),
                        timelst = np.linspace(0, 25, 51),
                        dist_func = qt.tracedist,
                        steadystate = rho_ss,
                        plot = False,
                        overlap_with = ax)[1])
    ax.scatter(theta_lst, out_lst, c = "b", label = "coherent")
    ax.set_xticks([0, np.pi, 2*np.pi])
    ax.set_xticklabels([r"$0$", r"$\pi$", r"$2\pi$"])
    ax.set_xlabel(r"complex plane angle for $\alpha$")
    ax.set_ylabel(r"time to reach steady state")

    rho_0_lst = [qt.thermal_dm(N, n),
                qt.fock_dm(N, n)]
    color = ["g", "r"]
    label = ["thermal", "number"]
    ls = [":", "--"]
    for i in [0,1]:
        x = qo.qdistance_to_ss(Ham = Ham,
                        c_ops = c_ops,
                        rho0 = rho_0_lst[i],
                        timelst = np.linspace(0, 25, 51),
                        dist_func = qt.tracedist,
                        steadystate = rho_ss,
                        plot = False,
                        overlap_with = ax)[1]
        ax.axhline(x, c = color[i], label = label[i], ls = ls[i])
        
    fig.suptitle(f"average photon number = {n}")
    print("blue dots --> coherent states with alpha = n * exp(1j * angle) \ngreen dotted line --> thermal state with n = n, \nred dashed line --> number state with n = n")
    plt.show()

# %%
N = 20
for n in range(4):
    sim(N, n)
# Out:
# blue dots --> coherent states with alpha = n * exp(1j * angle)
# green dotted line --> thermal state with n = n,
# red dashed line --> number state with n = n
# blue dots --> coherent states with alpha = n * exp(1j * angle)
# green dotted line --> thermal state with n = n,
# red dashed line --> number state with n = n
# blue dots --> coherent states with alpha = n * exp(1j * angle)
# green dotted line --> thermal state with n = n,
# red dashed line --> number state with n = n
# blue dots --> coherent states with alpha = n * exp(1j * angle)
# green dotted line --> thermal state with n = n,
# red dashed line --> number state with n = n

# %%
N = 20
for n in range(4,11):
    sim(N, n)
# Out:
# blue dots --> coherent states with alpha = n * exp(1j * angle)
# green dotted line --> thermal state with n = n,
# red dashed line --> number state with n = n
# blue dots --> coherent states with alpha = n * exp(1j * angle)
# green dotted line --> thermal state with n = n,
# red dashed line --> number state with n = n
# blue dots --> coherent states with alpha = n * exp(1j * angle)
# green dotted line --> thermal state with n = n,
# red dashed line --> number state with n = n
# blue dots --> coherent states with alpha = n * exp(1j * angle)
# green dotted line --> thermal state with n = n,
# red dashed line --> number state with n = n
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 3
#       1 N = 20
#       2 for n in range(4,11):
# ----> 3     sim(N, n)
#
# Cell In[38], line 12, in sim(N, n)
#      10 theta_lst = np.linspace(0, 2*np.pi, 37)[:-1]
#      11 for theta in theta_lst:
# ---> 12     out_lst.append(qo.qdistance_to_ss(Ham = Ham,
#      13                     c_ops = c_ops,
#      14                     rho0 = qt.coherent_dm(N, n * np.exp(1j*theta)),
#      15                     timelst = np.linspace(0, 25, 51),
#      16                     dist_func = qt.tracedist,
#      17                     steadystate = rho_ss,
#      18                     plot = False,
#      19                     overlap_with = ax)[1])
#      20 ax.scatter(theta_lst, out_lst, c = "b", label = "coherent")
#      21 ax.set_xticks([0, np.pi, 2*np.pi])
#
# File c:\Users\hendr\Documents\Python Scripts\#envQuantum\.venv\Lib\site-packages\pyqosc\general.py:54, in qdistance_to_ss(Ham, c_ops, rho0, timelst, dist_func, steadystate, plot, overlap_with, ss_err_tol, _stop_at_t_ss)
#      51 dist_lst.append(dist := dist_func(rho_t[i], rho_ss))
#      53 # Mark when steady state is reached.
# ---> 54 if mark and abs(dist - dist_func(rho_ss, rho_ss)) < ss_err_tol:
#      55     mark = False
#      56     t_ss = timelst[i]
#
# File c:\Users\hendr\Documents\Python Scripts\#envQuantum\.venv\Lib\site-packages\qutip\metrics.py:163, in tracedist(A, B, sparse, tol)
#     160 if A.dims != B.dims:
#     161     raise TypeError("A and B do not have same dimensions.")
# --> 163 diff = A - B
#     164 diff = diff.dag() * diff
#     165 vals = sp_eigs(diff.data, diff.isherm, vecs=False, sparse=sparse, tol=tol)
#
# File c:\Users\hendr\Documents\Python Scripts\#envQuantum\.venv\Lib\site-packages\qutip\qobj.py:474, in Qobj.__sub__(self, other)
#     470 def __sub__(self, other):
#     471     """
#     472     SUBTRACTION with Qobj on LEFT [ ex. Qobj-4 ]
#     473     """
# --> 474     return self + (-other)
#
# File c:\Users\hendr\Documents\Python Scripts\#envQuantum\.venv\Lib\site-packages\qutip\qobj.py:440, in Qobj.__add__(self, other)
#     438 else:  # case for matching quantum objects
#     439     out = Qobj()
# --> 440     out.data = self.data + other.data
#     441     out.dims = self.dims
#     442     if settings.auto_tidyup:
#
# File c:\Users\hendr\Documents\Python Scripts\#envQuantum\.venv\Lib\site-packages\scipy\sparse\_base.py:467, in _spbase.__add__(self, other)
#     465     if other.shape != self.shape:
#     466         raise ValueError("inconsistent shapes")
# --> 467     return self._add_sparse(other)
#     468 elif isdense(other):
#     469     other = np.broadcast_to(other, self.shape)
#
# File c:\Users\hendr\Documents\Python Scripts\#envQuantum\.venv\Lib\site-packages\scipy\sparse\_compressed.py:359, in _cs_matrix._add_sparse(self, other)
#     358 def _add_sparse(self, other):
# --> 359     return self._binopt(other, '_plus_')
#
# File c:\Users\hendr\Documents\Python Scripts\#envQuantum\.venv\Lib\site-packages\qutip\fastsparse.py:85, in fast_csr_matrix._binopt(self, other, op)
#      82 else:
#      83     data = np.empty(maxnnz, dtype=upcast(self.dtype, other.dtype))
# ---> 85 fn(self.shape[0], self.shape[1],
#      86    np.asarray(self.indptr, dtype=idx_dtype),
#      87    np.asarray(self.indices, dtype=idx_dtype),
#      88    self.data,
#      89    np.asarray(other.indptr, dtype=idx_dtype),
#      90    np.asarray(other.indices, dtype=idx_dtype),
#      91    other.data,
#      92    indptr, indices, data)
#      94 actual_nnz = indptr[-1]
#      95 indices = indices[:actual_nnz]
#
# KeyboardInterrupt:
