# %%
import numpy as np
import matplotlib.pyplot as plt
import qutip as qt
import pyqosc as qo
import scipy as sp

# %%
N = 20
vdp = qo.vdp(N)
rho_0 = qt.basis(N,0)*qt.basis(N,0).dag()
timelst = np.linspace(0, 10, 101)

# %%
qo.ss_distance(vdp.dynamics(), rho_0, timelst, True, qt.tracedist)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [0.9980703195387333,
#  0.9845360953863946,
#  0.9745500026426177,
#  0.9577086040275082,
#  0.9379746268887441,
#  0.9128130136060699,
#  0.8817122910759045,
#  0.8462066373540602,
#  0.8073102219372426,
#  0.7647773263500084,
#  0.7195229160361689,
#  0.6725089402866938,
#  0.6247365645297323,
#  0.5776390734446554,
#  0.5312409362492367,
#  0.4861540072809587,
#  0.44287356297896097,
#  0.40177868952275975,
#  0.3631389859872096,
#  0.3271253419022464,
#  0.2938229677524292,
#  0.2632452958761389,
#  0.23534774380461473,
#  0.21004061654973288,
#  0.18720078588138409,
#  0.16668179408270256,
#  0.14832249573005807,
#  0.13195410169671376,
#  0.11740581927497873,
#  0.10450922842711653,
#  0.09310158756686705,
#  0.08302819805754166,
#  0.0741439358382329,
#  0.06631437362299918,
# ...

# %%
qo.ss_qsl_funo(vdp,rho_0, init_tau = 6)
# Out:
# c:\Users\hendr\Documents\Python Scripts\#envQuantum\.venv\Lib\site-packages\scipy\integrate\_quadpack_py.py:577: ComplexWarning: Casting complex values to real discards the imaginary part
#   return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
# c:\Users\hendr\Documents\Python Scripts\#envQuantum\.venv\Lib\site-packages\pyqosc\general.py:1195: IntegrationWarning: The maximum number of subdivisions (101) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   return sp.integrate.quad(func, 0, tau, limit = quad_limit)[0]
# ...
